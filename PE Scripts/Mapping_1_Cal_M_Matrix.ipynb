# %%
import Mapping_Functions as mf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path_10X = 'genotyping/cycle_1'
path_40X = 'phenotyping'

# %%
#Tile_List_10X_1 = mf.Get_Tile_Coordinates(path_10X, n_well=1)
#Tile_List_40X_1 = mf.Get_Tile_Coordinates(path_40X, n_well=1)
#Tile_List_10X_6 = mf.Get_Tile_Coordinates(path_10X, n_well=6)
#Tile_List_40X_6 = mf.Get_Tile_Coordinates(path_40X, n_well=6)

# Tile_List_10X_1.to_csv('Tile_List_10X_1.csv')
# Tile_List_40X_1.to_csv('Tile_List_40X_1.csv')
# Tile_List_10X_6.to_csv('Tile_List_10X_6.csv')
# Tile_List_40X_6.to_csv('Tile_List_40X_6.csv')

Tile_List_10X_1 = pd.read_csv('Tile_List_10X_1.csv')
Tile_List_40X_1 = pd.read_csv('Tile_List_40X_1.csv')

# %%
M_10X_1 = mf.Arrange_Tiles(Tile_List_10X_1, h=2304, w=2304, plot_location=False)
M_40X_1 = mf.Arrange_Tiles(Tile_List_40X_1, h=2304, w=2304, plot_location=False)

# M_10X_6 = mf.Arrange_Tiles(Tile_List_10X_6, h=2304, w=2304, plot_location=False)
# M_40X_6 = mf.Arrange_Tiles(Tile_List_40X_6, h=2304, w=2304, plot_location=False)

np.save('M_10X.npy', M_10X_1)
np.save('M_40X.npy', M_40X_1)

# M_10X = np.load('M_10X.npy')
# M_40X = np.load('M_40X.npy')

# pd.DataFrame(M_10X).to_csv('M_10X.csv')

# print((M_40X_1 - M_40X_6).sum())

# print(M_10X_6)

# %%
# %matplotlib notebook
M_10X = np.load('M_10X.npy')
M_40X = np.load('M_40X.npy')

# M_10X = np.transpose(M_10X)
# M_40X = np.transpose(M_40X)

# mf.Check_Tile_Configuration(path_10X, M, file_type='nd2', plot_align = False, print_config = True, plot_tiles = True)
# mf.Check_Tile_Configuration(path_40X, M, file_type='nd2', plot_align = False, print_config = True, plot_tiles = True)

mf.Plot_4_Center_Tiles(M_10X, path_10X)
# mf.Plot_4_Center_Tiles(M_40X, path_40X)

# np.save('M_10X.npy', M_10X)
# np.save('M_40X.npy', M_40X)

# plt.show()
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %%
# pd.DataFrame( np.load('M_10X.npy')).to_csv('M_10.csv')
# pd.DataFrame( np.load('M_40X.npy')).to_csv('M_40.csv')
